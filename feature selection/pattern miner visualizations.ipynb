# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')

# %%
chunks = pd.read_csv('datasets/DataSet01.csv', chunksize=8500000)

# %%
df = []
for chunk in chunks:
    df = chunk
    break
# Out:
# C:\Users\pc\Anaconda3\envs\gpuconda\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (5,6,13,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.tail()
# Out:
#          ONLINE_STORE_CATEGORY TRN_SLS_DTE TRN_STRT_TM  MSTR_PERSONA_KEY  \
# 8499995             1758427098   1/15/2018    20:09:23       33110393834
# 8499996               73168914   1/15/2018    19:45:34       33110695037
# 8499997             1465291146   1/15/2018    19:47:54       32896059145
# 8499998             1841427194   1/15/2018    19:45:34       33102748789
# 8499999             1390981718   1/15/2018    20:38:47       32898818254
#
#          PRIMARY_PRODUCT_CODE SIZE_CDE CLOR_CDE  DEPT_NBR  SELLING_PRICE  \
# 8499995            1300794994    93298       20       464          13.81
# 8499996            1447070860    31007      100       714          14.00
# 8499997             732495793    14778      410       656          42.48
# 8499998           11035718988    33904       60       443          60.00
# 8499999             812289637        0        0       830           5.00
#
#          PRODUCT_CLASS_01  PRODUCT_CLASS_02   BRTH_DTE FMALE_IND MRYD_IND  \
# ...

# %%
# plt.scatter(df['2017_M12_RETURNED_AMT'],df['AGE'], c='black', alpha=0.1)

# %%
df1 = df.groupby('EDUC_LVL_NBR').mean()

# %%
plt.plot(df1.index,df1['2017_M7_RETURNED_AMT'], label="7")
plt.plot(df1.index,df1['2017_M8_RETURNED_AMT'], label="8")
plt.plot(df1.index,df1['2017_M9_RETURNED_AMT'], label="9")
plt.plot(df1.index,df1['2017_M10_RETURNED_AMT'], label="10")
plt.plot(df1.index,df1['2017_M11_RETURNED_AMT'], label="11")
plt.plot(df1.index,df1['2017_M12_RETURNED_AMT'], label="12")
plt.legend()
# plt.hist(df1.index,df1['2017_M12_RETURNED_AMT'])

# %%
df1 = df.groupby('FREQUENCY_OF_VISIT').mean()

# %%
plt.plot(df1.index,df1['2017_M7_RETURNED_AMT'], label="7")
plt.plot(df1.index,df1['2017_M8_RETURNED_AMT'], label="8")
plt.plot(df1.index,df1['2017_M9_RETURNED_AMT'], label="9")
plt.plot(df1.index,df1['2017_M10_RETURNED_AMT'], label="10")
plt.plot(df1.index,df1['2017_M11_RETURNED_AMT'], label="11")
plt.plot(df1.index,df1['2017_M12_RETURNED_AMT'], label="12")
plt.legend()

# %%
df1 = df.groupby('FMALE_IND').mean()

# %%
plt.plot(df1.index,df1['2017_M7_RETURNED_AMT'], label="7")
plt.plot(df1.index,df1['2017_M8_RETURNED_AMT'], label="8")
plt.plot(df1.index,df1['2017_M9_RETURNED_AMT'], label="9")
plt.plot(df1.index,df1['2017_M10_RETURNED_AMT'], label="10")
plt.plot(df1.index,df1['2017_M11_RETURNED_AMT'], label="11")
plt.plot(df1.index,df1['2017_M12_RETURNED_AMT'], label="12")
plt.legend()

# %%
df1 = df.groupby('MRYD').mean()

# %%
plt.plot(df1.index,df1['2017_M7_RETURNED_AMT'], label="7")
plt.plot(df1.index,df1['2017_M8_RETURNED_AMT'], label="8")
plt.plot(df1.index,df1['2017_M9_RETURNED_AMT'], label="9")
plt.plot(df1.index,df1['2017_M10_RETURNED_AMT'], label="10")
plt.plot(df1.index,df1['2017_M11_RETURNED_AMT'], label="11")
plt.plot(df1.index,df1['2017_M12_RETURNED_AMT'], label="12")
plt.legend()

# %%
df1 = df.groupby('AGE').mean()

# %%
plt.plot(df1.index,df1['2017_M7_RETURNED_AMT'], label="7")
plt.plot(df1.index,df1['2017_M8_RETURNED_AMT'], label="8")
plt.plot(df1.index,df1['2017_M9_RETURNED_AMT'], label="9")
plt.plot(df1.index,df1['2017_M10_RETURNED_AMT'], label="10")
plt.plot(df1.index,df1['2017_M11_RETURNED_AMT'], label="11")
plt.plot(df1.index,df1['2017_M12_RETURNED_AMT'], label="12")
plt.legend()
